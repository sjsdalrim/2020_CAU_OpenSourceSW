# %% [markdown]
# # **Open Source SW and Python Programming Project: Implementation of Subway Navigation**
#
# In this project, you will implement a navigation system for Seoul subway stations, especially **step by step**

# %% [markdown]
# # 0. Initialization
#
# Read subway station information by reading the file **simplified_subway_info_english.xlsx** or **simplified_subway_info_korean.xlsx**
# *  The excel file contains subway station information of Seoul subway line 1 ~ 4
# *  When you execute this sourcecode, you MUST upload these files in your Colab runtime environment
# *   **MUST NOT** change this code cell

# %%
import xlrd

# Read data file
data = xlrd.open_workbook("simplified_subway_info_english.xlsx")
data = data.sheet_by_name('Sheet1')

# Store the loaded book object as a string list in subwayStation variable
subwayStation = []
for line in range(4) :
    cur = [x for x in data.col_values(line) if x]    
    subwayStation.append(cur[1:])

# %% [markdown]
# # 1. Your implementation
# Let's start the implementation of a subway naviation system by using the loaded subway station information :)
#
# *   You can access the subway station information by referring to **subwayStation** variable (list type)

# %%
first_value = None

while first_value not in [3] :
  print()
  print('************************************************************')
  print('1. Display subway line information (Line 1 ~ 4)')
  print('2. Display subway station information')
  print('3. Exit')
  print('************************************************************')
  first_value = int(input('Please choose one of the options (1 - 3): '))
  
  if first_value == 1 :
    
    second_value = None
    
    while second_value not in [1, 2, 3, 4] :
      print()
      print('************************************************************')
      print('Subway Line information service')
      print('************************************************************')
      second_value = int(input('>> Please enter a subway line number (1 - 4): '))
      
      if second_value in [1, 2, 3, 4] :
        print()
        print( subwayStation[second_value - 1] )
      
      else :
        print()
        print('Wrong input')
        continue

  elif first_value == 2 :
    
    third_value = None

    while third_value not in [1] :
      print()
      print('************************************************************')
      print('Subway Station information service')
      print('************************************************************')
      stat_name = input('>> Please enter a subway station name: ')
      
      if (stat_name in subwayStation[0]) or (stat_name in subwayStation[1]) or (stat_name in subwayStation[2]) or (stat_name in subwayStation[3]) :
        
        line_num = None

        if (stat_name in subwayStation[0]) and (stat_name in subwayStation[1]) and (stat_name in subwayStation[2]) and (stat_name in subwayStation[3]) :
          line_num = '1 and 2 and 3 and 4'
        elif (stat_name in subwayStation[0]) and (stat_name in subwayStation[1]) and (stat_name in subwayStation[2]) :
          line_num = '1 and 2 and 3'
        elif (stat_name in subwayStation[0]) and (stat_name in subwayStation[1]) and (stat_name in subwayStation[3]) :
          line_num = '1 and 2 and 4'
        elif (stat_name in subwayStation[0]) and (stat_name in subwayStation[2]) and (stat_name in subwayStation[3]) :
          line_num = '1 and 3 and 4'
        elif (stat_name in subwayStation[1]) and (stat_name in subwayStation[2]) and (stat_name in subwayStation[3]) :
          line_num = '2 and 3 and 4'
        elif (stat_name in subwayStation[0]) and (stat_name in subwayStation[1]) :
          line_num = '1 and 2'
        elif (stat_name in subwayStation[0]) and (stat_name in subwayStation[2]) :
          line_num = '1 and 3'
        elif (stat_name in subwayStation[0]) and (stat_name in subwayStation[3]) :
          line_num = '1 and 4'
        elif (stat_name in subwayStation[1]) and (stat_name in subwayStation[2]) :
          line_num = '2 and 3'
        elif (stat_name in subwayStation[1]) and (stat_name in subwayStation[3]) :
          line_num = '2 and 4'
        elif (stat_name in subwayStation[2]) and (stat_name in subwayStation[3]) :
          line_num = '3 and 4'
        elif (stat_name in subwayStation[0]) :
          line_num = '1'
        elif (stat_name in subwayStation[1]) :
          line_num = '2'
        elif (stat_name in subwayStation[2]) :
          line_num = '3'
        elif (stat_name in subwayStation[3]) :
          line_num = '4'

        print()
        print( stat_name, 'station is in Line',  line_num)
        break
      
      else :
        print()
        print('Wrong input')
        continue

  elif first_value == 3 :
    print()
    print('Exit Navigation')
    break

  else :
    print()
    print('Wrong input')
    continue
