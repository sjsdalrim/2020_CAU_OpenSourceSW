# %% [markdown]
# # **Open Source SW and Python Programming Project: Implementation of Subway Navigation**
#
# In this project, you will implement a navigation system for Seoul subway stations, especially **step by step**

# %% [markdown]
# # 0. Initialization
#
# Read subway station information by reading the file **simplified_subway_info_english.xlsx** or **simplified_subway_info_korean.xlsx**
# *  The excel file contains subway station information of Seoul subway line 1 ~ 4
# *  When you execute this sourcecode, you MUST upload these files in your Colab runtime environment
# *   **MUST NOT** change this code cell

# %%
import xlrd

# Read data file
data = xlrd.open_workbook("simplified_subway_info_english.xlsx")
data = data.sheet_by_name('Sheet1')

# Store the loaded book object as a string list in subwayStation variable
subwayStation = []
for line in range(4) :
    cur = [x for x in data.col_values(line) if x]    
    subwayStation.append(cur[1:])

# %% [markdown]
# # 1. Your implementation
# Let's start the implementation of a subway naviation system by using the loaded subway station information :)
#
# *   You can access the subway station information by referring to **subwayStation** variable (list type)

# %%
tuL1 = tuple(subwayStation[0])
tuL2 = tuple(subwayStation[1])
tuL3 = tuple(subwayStation[2])
tuL4 = tuple(subwayStation[3])

subwayStation = {'Line1':tuL1, 'Line2':tuL2, 'Line3':tuL3, 'Line4':tuL4}

#for key in subwayStation.keys() :
#  print(key)
#for value in subwayStation.values() :
#  print(value)

# %%
def dispSubwayLineInfo() :
  
  second_value = None
    
  while second_value not in [1, 2, 3, 4] :
    print()
    print('************************************************************')
    print('Subway Line information service')
    print('************************************************************')
    second_value = int(input('>> Please enter a subway line number (1 - 4): '))
      
    if second_value in [1] :
      print()
      print( subwayStation['Line1'] )

    elif second_value in [2] :
      print()
      print( subwayStation['Line2'] )

    elif second_value in [3] :
      print()
      print( subwayStation['Line3'] )

    elif second_value in [4] :
      print()
      print( subwayStation['Line4'] )
      
    else :
      print()
      print('Wrong input')
      continue


def dispSubwayStationInfo() :
  
  third_value = None

  while third_value not in [1] :
    print()
    print('************************************************************')
    print('Subway Station information service')
    print('************************************************************')
    stat_name = input('>> Please enter a subway station name: ')
      
    if (stat_name in subwayStation['Line1']) or (stat_name in subwayStation['Line2']) or (stat_name in subwayStation['Line3']) or (stat_name in subwayStation['Line4']) :
        
      line_num = None

      if (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line2']) and (stat_name in subwayStation['Line3']) and (stat_name in subwayStation['Line4']) :
        line_num = '1 and 2 and 3 and 4'
      elif (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line2']) and (stat_name in subwayStation['Line3']) :
        line_num = '1 and 2 and 3'
      elif (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line2']) and (stat_name in subwayStation['Line4']) :
        line_num = '1 and 2 and 4'
      elif (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line3']) and (stat_name in subwayStation['Line4']) :
        line_num = '1 and 3 and 4'
      elif (stat_name in subwayStation['Line2']) and (stat_name in subwayStation['Line3']) and (stat_name in subwayStation['Line4']) :
        line_num = '2 and 3 and 4'
      elif (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line2']) :
        line_num = '1 and 2'
      elif (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line3']) :
        line_num = '1 and 3'
      elif (stat_name in subwayStation['Line1']) and (stat_name in subwayStation['Line4']) :
        line_num = '1 and 4'
      elif (stat_name in subwayStation['Line2']) and (stat_name in subwayStation['Line3']) :
        line_num = '2 and 3'
      elif (stat_name in subwayStation['Line2']) and (stat_name in subwayStation['Line4']) :
        line_num = '2 and 4'
      elif (stat_name in subwayStation['Line3']) and (stat_name in subwayStation['Line4']) :
        line_num = '3 and 4'
      elif (stat_name in subwayStation['Line1']) :
        line_num = '1'
      elif (stat_name in subwayStation['Line2']) :
        line_num = '2'
      elif (stat_name in subwayStation['Line3']) :
        line_num = '3'
      elif (stat_name in subwayStation['Line4']) :
        line_num = '4'

      print()
      print( stat_name, 'station is in Line',  line_num)
      break
      
    else :
      print()
      print('Wrong input')
      continue

# %%
#### function of option 3

def dispSubwayPath() :

  fourth_value = None
    
  while fourth_value not in [1] :
    
    print()
    depa_stat = None
    arri_stat = None
    depa_stat = input('>> Please enter a departure subway station name: ')
    arri_stat = input('>> Please enter a arrival subway station name: ')

    if ((depa_stat in tuL1) or (depa_stat in tuL2) or (depa_stat in tuL3) or (depa_stat in tuL4)) and ((arri_stat in tuL1) or (arri_stat in tuL2) or (arri_stat in tuL3) or (arri_stat in tuL4)) :
      
      print()
      depa_num = 0
      arri_num = 0
      
      if (depa_stat in tuL1) and (arri_stat in tuL1) : #### no trans Line1 to Line1
        
        while (depa_num<63) :
          if (tuL1[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<63) :
          if (tuL1[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<arri_num) :
          for i in range(arri_num-depa_num+1) :
            print(tuL1[depa_num+i], end='  ')
        else :
          for i in range(depa_num-arri_num+1) :
            print(tuL1[depa_num-i], end='  ')
    
      elif (depa_stat in tuL2) and (arri_stat in tuL2) : #### no trans Line2 to Line2
        
        while (depa_num<44) :
          if (tuL2[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<44) :
          if (tuL2[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<arri_num) :
          for i in range(arri_num-depa_num+1) :
            print(tuL2[depa_num+i], end='  ')
        else :
          for i in range(depa_num-arri_num+1) :
            print(tuL2[depa_num-i], end='  ')

      elif (depa_stat in tuL3) and (arri_stat in tuL3) : #### no trans Line3 to Line3
        
        while (depa_num<45) :
          if (tuL3[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<45) :
          if (tuL3[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<arri_num) :
          for i in range(arri_num-depa_num+1) :
            print(tuL3[depa_num+i], end='  ')
        else :
          for i in range(depa_num-arri_num+1) :
            print(tuL3[depa_num-i], end='  ')

      elif (depa_stat in tuL4) and (arri_stat in tuL4) : #### no trans Line4 to Line4
        
        while (depa_num<49) :
          if (tuL4[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<49) :
          if (tuL4[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<arri_num) :
          for i in range(arri_num-depa_num+1) :
            print(tuL4[depa_num+i], end='  ')
        else :
          for i in range(depa_num-arri_num+1) :
            print(tuL4[depa_num-i], end='  ')

      elif (depa_stat in tuL1) and (arri_stat in tuL2) : #### Line1 to Line2
        
        while (depa_num<63) :
          if (tuL1[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<44) :
          if (tuL2[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<32) :
          for i in range(32-depa_num+1) :
            print(tuL1[depa_num+i], end='  ')
        else :
          for i in range(depa_num-32+1) :
            print(tuL1[depa_num-i], end='  ')
        print('<<transfer to Line 2>>', end='  ')
        if (arri_num<33) :
          for i in range(33-arri_num+1) :
            print(tuL2[33-i], end='  ')
        else :
          for i in range(arri_num-33+1) :
            print(tuL2[33+i], end='  ')

      elif (depa_stat in tuL1) and (arri_stat in tuL3) : #### Line1 to Line3
        
        while (depa_num<63) :
          if (tuL1[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<45) :
          if (tuL3[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<30) :
          for i in range(30-depa_num+1) :
            print(tuL1[depa_num+i], end='  ')
        else :
          for i in range(depa_num-30+1) :
            print(tuL1[depa_num-i], end='  ')
        print('<<transfer to Line 3>>', end='  ')
        if (arri_num<20) :
          for i in range(20-arri_num+1) :
            print(tuL3[20-i], end='  ')
        else :
          for i in range(arri_num-20+1) :
            print(tuL3[20+i], end='  ')

      elif (depa_stat in tuL1) and (arri_stat in tuL3) : #### Line1 to Line4
        
        while (depa_num<63) :
          if (tuL1[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<49) :
          if (tuL4[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<33) :
          for i in range(33-depa_num+1) :
            print(tuL1[depa_num+i], end='  ')
        else :
          for i in range(depa_num-33+1) :
            print(tuL1[depa_num-i], end='  ')
        print('<<transfer to Line 4>>', end='  ')
        if (arri_num<17) :
          for i in range(17-arri_num+1) :
            print(tuL4[17-i], end='  ')
        else :
          for i in range(arri_num-17+1) :
            print(tuL4[17+i], end='  ')
      
      elif (depa_stat in tuL2) and (arri_stat in tuL1) : #### Line2 to Line1
        
        while (depa_num<44) :
          if (tuL2[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<63) :
          if (tuL1[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<33) :
          for i in range(33-depa_num+1) :
            print(tuL2[depa_num+i], end='  ')
        else :
          for i in range(depa_num-33+1) :
            print(tuL2[depa_num-i], end='  ')
        print('<<transfer to Line 1>>', end='  ')
        if (arri_num<32) :
          for i in range(32-arri_num+1) :
            print(tuL1[32-i], end='  ')
        else :
          for i in range(arri_num-32+1) :
            print(tuL1[32+i], end='  ')
      
      elif (depa_stat in tuL2) and (arri_stat in tuL3) : #### Line2 to Line3
        
        while (depa_num<44) :
          if (tuL2[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<45) :
          if (tuL3[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<11) :
          for i in range(11-depa_num+1) :
            print(tuL2[depa_num+i], end='  ')
        else :
          for i in range(depa_num-11+1) :
            print(tuL2[depa_num-i], end='  ')
        print('<<transfer to Line 3>>', end='  ')
        if (arri_num<31) :
          for i in range(31-arri_num+1) :
            print(tuL3[31-i], end='  ')
        else :
          for i in range(arri_num-31+1) :
            print(tuL3[31+i], end='  ')
      
      elif (depa_stat in tuL2) and (arri_stat in tuL4) : #### Line2 to Line4
        
        while (depa_num<44) :
          if (tuL2[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<49) :
          if (tuL4[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<8) :
          for i in range(8-depa_num+1) :
            print(tuL2[depa_num+i], end='  ')
        else :
          for i in range(depa_num-8+1) :
            print(tuL2[depa_num-i], end='  ')
        print('<<transfer to Line 4>>', end='  ')
        if (arri_num<24) :
          for i in range(24-arri_num+1) :
            print(tuL4[24-i], end='  ')
        else :
          for i in range(arri_num-24+1) :
            print(tuL1[24+i], end='  ')

      elif (depa_stat in tuL3) and (arri_stat in tuL1) : #### Line3 to Line1
        
        while (depa_num<45) :
          if (tuL3[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<63) :
          if (tuL1[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<20) :
          for i in range(20-depa_num+1) :
            print(tuL3[depa_num+i], end='  ')
        else :
          for i in range(depa_num-20+1) :
            print(tuL3[depa_num-i], end='  ')
        print('<<transfer to Line 1>>', end='  ')
        if (arri_num<30) :
          for i in range(30-arri_num+1) :
            print(tuL1[30-i], end='  ')
        else :
          for i in range(arri_num-30+1) :
            print(tuL1[30+i], end='  ')

      elif (depa_stat in tuL3) and (arri_stat in tuL2) : #### Line3 to Line2
        
        while (depa_num<45) :
          if (tuL3[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<44) :
          if (tuL2[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<31) :
          for i in range(31-depa_num+1) :
            print(tuL3[depa_num+i], end='  ')
        else :
          for i in range(depa_num-31+1) :
            print(tuL3[depa_num-i], end='  ')
        print('<<transfer to Line 2>>', end='  ')
        if (arri_num<11) :
          for i in range(11-arri_num+1) :
            print(tuL2[11-i], end='  ')
        else :
          for i in range(arri_num-11+1) :
            print(tuL2[11+i], end='  ')

      elif (depa_stat in tuL3) and (arri_stat in tuL4) : #### Line3 to Line4
        
        while (depa_num<45) :
          if (tuL3[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<49) :
          if (tuL4[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<22) :
          for i in range(22-depa_num+1) :
            print(tuL3[depa_num+i], end='  ')
        else :
          for i in range(depa_num-22+1) :
            print(tuL3[depa_num-i], end='  ')
        print('<<transfer to Line 4>>', end='  ')
        if (arri_num<14) :
          for i in range(14-arri_num+1) :
            print(tuL4[14-i], end='  ')
        else :
          for i in range(arri_num-14+1) :
            print(tuL4[14+i], end='  ')

      elif (depa_stat in tuL4) and (arri_stat in tuL1) : #### Line4 to Line1
        
        while (depa_num<49) :
          if (tuL4[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<63) :
          if (tuL1[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<17) :
          for i in range(17-depa_num+1) :
            print(tuL4[depa_num+i], end='  ')
        else :
          for i in range(depa_num-17+1) :
            print(tuL4[depa_num-i], end='  ')
        print('<<transfer to Line 1>>', end='  ')
        if (arri_num<33) :
          for i in range(33-arri_num+1) :
            print(tuL1[33-i], end='  ')
        else :
          for i in range(arri_num-33+1) :
            print(tuL1[33+i], end='  ')

      elif (depa_stat in tuL4) and (arri_stat in tuL2) : #### Line4 to Line2
        
        while (depa_num<49) :
          if (tuL4[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<44) :
          if (tuL2[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<24) :
          for i in range(24-depa_num+1) :
            print(tuL4[depa_num+i], end='  ')
        else :
          for i in range(depa_num-24+1) :
            print(tuL4[depa_num-i], end='  ')
        print('<<transfer to Line 2>>', end='  ')
        if (arri_num<8) :
          for i in range(8-arri_num+1) :
            print(tuL2[8-i], end='  ')
        else :
          for i in range(arri_num-8+1) :
            print(tuL2[8+i], end='  ')

      elif (depa_stat in tuL4) and (arri_stat in tuL3) : #### Line4 to Line3
        
        while (depa_num<49) :
          if (tuL4[depa_num] == depa_stat) :
            break
          else:
            depa_num += 1
        while (arri_num<45) :
          if (tuL3[arri_num] == arri_stat) :
            break
          else :
            arri_num += 1
        
        if (depa_num<14) :
          for i in range(14-depa_num+1) :
            print(tuL4[depa_num+i], end='  ')
        else :
          for i in range(depa_num-14+1) :
            print(tuL4[depa_num-i], end='  ')
        print('<<transfer to Line 3>>', end='  ')
        if (arri_num<22) :
          for i in range(22-arri_num+1) :
            print(tuL3[22-i], end='  ')
        else :
          for i in range(arri_num-22+1) :
            print(tuL3[22+i], end='  ')

      print()
      break

    else :
      print()
      print('Wrong input')
      continue

# %%
first_value = None

while first_value not in [4] :
  print()
  print('************************************************************')
  print('1. Display subway line information (Line 1 ~ 4)')
  print('2. Display subway station information')
  print('3. Find a path between two subway stations')
  print('4. Exit')
  print('************************************************************')
  first_value = int(input('Please choose one of the options (1 - 4): '))
  
  if first_value == 1 :
    
    dispSubwayLineInfo()

  elif first_value == 2 :
    
    dispSubwayStationInfo()
  
  elif first_value == 3 :

    dispSubwayPath()

  elif first_value == 4 :
    print()
    print('Exit Navigation')
    break

  else :
    print()
    print('Wrong input')
    continue
